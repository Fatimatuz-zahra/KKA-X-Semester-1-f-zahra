# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimatuz-zahra/KKA-X-Semester-1-f-zahra/blob/main/1_Fungsi_print_Zahra_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama : Fatimatuz Zahra
#
# kelas : X.1
#
# absen : 10

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
print ("Fatimatuz zahra")
# Out:
# Fatimatuz zahra

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
nama_idola = "jaemin"
print(nama_idola)
# Out:
# jaemin

# %%
usia = 24
print(usia)
# Out:
# 24

# %%
nama_saudara = "ayu wahyuni"
print(nama_saudara)
# Out:
# ayu wahyuni

# %%
jumlah_saudara = 1
print(jumlah_saudara)
# Out:
# 1

# %% [markdown]
# #Menampilkan Nilai Variabel dan String

# %%
print ("Nama idola saya adalah",nama_idola,".Usianya adalah",usia,"tahun.")
# Out:
# Nama idola saya adalah jaemin .Usianya adalah 15 tahun.

# %%
print ("Nama idola saya adalah "+nama_idola+". Usianya adalah "+str(usia)+"tahun.")
# Out:
# Nama idola saya adalah jaemin. Usianya adalah 15tahun.

# %% [markdown]
# #Escape String

# %%
print("Nama: Fatimatuz zahra")
print("Kelas: X.1")
print("No. Absen: 10")
# Out:
# Nama: Fatimatuz zahra
# Kelas: X.1
# No. Absen: 10

# %%
print("Nama: Fatimatuz zahra\nKelas: X.1\nNo. Absen: 10")
# Out:
# Nama: Fatimatuz zahra
# Kelas: X.1
# No. Absen: 10

# %%
print("""Nama\t\t: Fatimatuz zahra "
Kelas\t\t: X.1
No. Absen\t: 10""")
# Out:
# Nama		: Fatimatuz zahra "
# Kelas		: X.1
# No. Absen	: 10

# %%
print(f"Nama idola saya adalah {nama_idola}. Usianya adalah {usia} tahun.")
# Out:
# Nama idola saya adalah jaemin. Usianya adalah 15 tahun.

# %%
print ("Halo Nama Saya Habib Jafar")
# Out:
# Halo Nama Saya Habib Jafar

# %%
print ('Halo Nama Saya Habib Jafar')
# Out:
# Halo Nama Saya Habib Jafar

# %%
print ('Halo Nama Saya Habib Ja\'far')
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print ("Halo Nama Saya Habib Ja'far")
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print ("Bu Sinta Berkata, \"Tolong Fokus ke TV Sejenak")
# Out:
# Bu Sinta Berkata, "Tolong Fokus ke TV Sejenak

# %%
print ("Silahkan simpan file tugas KKA di folder Local disk D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Silahkan simpan file tugas KKA di folder Local disk D:\MAN Demak\KKA\Tugas

# %%
print ('Bu Sinta Berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\\MAN Demak\\Jadwal Piket."\n\nSenin\tSelas\tRabu\nJielo\tHasbi\tNaufal\t\nAzam\tA\'inun\tNurul\t')
# Out:
# Bu Sinta Berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\MAN Demak\Jadwal Piket."
#
# Senin	Selas	Rabu
# Jielo	Hasbi	Naufal
# Azam	A'inun	Nurul

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1 = "Dias"
nama_siswa_2 = "Disa"

print (nama_siswa_1, end=" ")
print (nama_siswa_2)
# Out:
# Dias Disa

# %%
print (nama_siswa_1, nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2, sep= "-")
# Out:
# Dias-Disa

# %%
nama_siswa_3 = "kinan"
nama_siswa_4 = "Azka"
nama_siswa_5 = "Naufal"
nama_siswa_6 = "Ridho"

print (nama_siswa_6,nama_siswa_3,nama_siswa_4,nama_siswa_4, sep="/")
# Out:
# Ridho/kinan/Azka/Azka

# %%
print(nama_siswa_4, end="*")
print(nama_siswa_4, end="*")
print(nama_siswa_5, end="*")
print(nama_siswa_3, end="*")
print(nama_siswa_6, end="")
# Out:
# Azka*Azka*Naufal*kinan*Ridho
