# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimatuz-zahra/KKA-X-Semester-1-f-zahra/blob/main/Salinan_dari_2_Tipe_Variabel_Zahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print ("zzahrou.2025@gmail.com")
print ("zzahrou.2025@gmail.com")
print ("zzahrou.2025@gmail.com")
# Out:
# zzahrou.2025@gmail.com
# zzahrou.2025@gmail.com
# zzahrou.2025@gmail.com

# %%
email_user_1 = "zzahrou.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# zzahrou.2025@gmail.com
# zzahrou.2025@gmail.com
# zzahrou.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Sensitif terhadap kapital
email_user_2 = "keenan akbar"
print(Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4289649791.py in <cell line: 0>()
#       1 #Sensitif terhadap kapital
#       2 email_user_2 = "keenan akbar"
# ----> 3 print(Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "keenan akbar"
print(email_user_2)
# Out:
# keenan akbar

# %%
emailuser2 = "Yoga Armando"

print(emailuser2)
# Out:
# Yoga Armando

# %%
#Hanya boleh menggunakan huruf angka dan underscore
email user 3 = "Dimas Esa"
print(email user 3)
# Out:
#   File "/tmp/ipython-input-3484499531.py", line 2
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailUser3 = "Dimas Esa"
print(emailUser3)
# Out:
# Dimas Esa

# %%
#Tidak boleh di dahului angka
4_email_user = "Hanafi Naufal"
print(4_email_user)
# Out:
#   File "/tmp/ipython-input-2466022454.py", line 2
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
for = "Naufal Fajri"
print(for)
# Out:
#   File "/tmp/ipython-input-3217420691.py", line 2
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"
print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3121028777.py in <cell line: 0>()
#       1 print = "Alif Nadya"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"
print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1777838563.py in <cell line: 0>()
#       1 Print = "Alif Nadya"
# ----> 2 print(Print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"
print(Print)
# Out:
# Alif Nadya

# %%
_ = "Azka Alifta"

# %%
print(_)
# Out:
# Azka Alifta

# %%
_ = "Kenzo Aliando"

# %%
print(_)
# Out:
# Kenzo Aliando

# %% [markdown]
# #Assignment

# %%
#single assignment
beratbadansiswa1 = 90
print(beratbadansiswa1)
# Out:
# 90

# %%
#Multiple assignment
nilai_kka_dias, nilai_kka_azka = 99, 98

print(nilai_kka_dias)
print(nilai_kka_azka)
# Out:
# 99
# 98

# %%
nilai_kka_dias, nilai_kka_azka = 99, 98, 70

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1966421120.py in <cell line: 0>()
# ----> 1 nilai_kka_dias, nilai_kka_azka = 99, 98, 70
#       2
#       3 print(nilai_kka_azka)
#       4 print(nilai_kka_dias)
#
# ValueError: too many values to unpack (expected 2)

# %%
#Chain assignment
usia_anwar = usia_sahda = 20

print(usia_anwar)
print(usia_sahda)
# Out:
# 20
# 20

# %% [markdown]
# #Latihan Soal

# %%
nama = "andi"
print(nama)
# Out:
# andi

# %%
nama, umur, kelas = "Budi", 15, "9A"

print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %%
berat_andi = berat_siti = berat_eko = 45.5

print(berat_andi, berat_siti, berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #Cara Penulisan Operasi Aritmatika pada Python

# %%
#Tanpa variabel
print (8+2)
# Out:
# 10

# %%
#Operan disimpan ke variabel
kelereng_dias = 2
kelerang_azka = 8
print(kelereng_dias + kelerang_azka)
# Out:
# 10

# %%
#Hasil operasi disimpan di variabel
total_kelereng = 8+2
print(total_kelereng)
# Out:
# 10

# %%
#operand dan hasil operasi di simpan ke variabel
kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng_azka+kelereng_dias
print (total_kelereng)
# Out:
# 10

# %% [markdown]
# #Latihan Soal

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print (banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print (total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Jenis-jenis operator Aritmatima

# %%
#Penjumlahan
iphone_azka = 5
iphone_anwar = 7

total_iphone = iphone_azka + iphone_anwar
print(total_iphone)
# Out:
# 12

# %%
#Selisih
iphone_azka = 5
iphone_anwar = 7

selisih_iphone = iphone_anwar - iphone_azka
print(selisih_iphone)
# Out:
# 2

# %%
#Perkalian
type_iphone = "Iphone 16 pro max"
dus_iphone_azka = 3
banyak_iphone_per_dus = 12

total_iphone = dus_iphone_azka + banyak_iphone_per_dus
print(total_iphone)
# Out:
# 15

# %%
#Pembagian
total_iphone = 36
anak_yatim = 7

iphone_per_anak = total_iphone / anak_yatim
print(iphone_per_anak)
# Out:
# 5.142857142857143

# %%
#Pembagian Bulat
total_iphone = 36
anak_yatim = 7

iphone_per_anak = total_iphone // anak_yatim
print(iphone_per_anak)
# Out:
# 5

# %%
#sisa
total_iphone = 36
anak_yatim = 7

sisa_iphone = total_iphone % anak_yatim
print(sisa_iphone)
# Out:
# 1

# %%
#pengurangan
iphone_azka=5
iphone_anwar=7

# %%
#sisa iphone
total_iphone = 36
anak_yatim = 7

sisa_iphone =

# %%
sisi = 2
luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 4

# %%
sisi = 3
volume = sisi ** 3

print(volume)
# Out:
# 27

# %%
VOLUME_KUBUS = 8
sisi = VOLUME_KUBUS ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# #Jenis Tipe Variabel

# %%
a ="handayarni"
print(a)
type(a)
# Out:
# handayarni
# str

# %%
b = -0.001
print(b)
type(b)
# Out:
# -0.001
# float

# %%
c =-58
print (c)
type(c)
# Out:
# -58
# int

# %%
d = True
print (d)
type(d)
# Out:
# True
# bool

# %%
d = TRUE
print (d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1234245771.py in <cell line: 0>()
# ----> 1 d = TRUE
#       2 print (d)
#       3 type(d)
#
# NameError: name 'TRUE' is not defined

# %%
e =1,89
print(e)
type(e)
# Out:
# (1, 89)
# tuple

# %%
x ="False"
print (x)
type(x)
# Out:
# False
# str

# %%
type (-500)
# Out:
# int

# %%
k = float(88)
print(k)
type(k)
# Out:
# 88.0
# float

# %%
z=float(-100)
print (z)
type(z)
# Out:
# -100.0
# float

# %% [markdown]
# #Perubahan Type Variabel

# %%
f=8.9
print (f)
type(f)
# Out:
# 8.9
# float

# %%
f=int(f)
print (f)
type (f)
# Out:
# 8
# int

# %%
g=-2.05
print (g)
type (g)
# Out:
# -2.05
# float

# %%
g=int(g)
print (g)
type (g)
# Out:
# -2
# int

# %%
g=bool(g)
print(g)
type (g)
# Out:
# True
# bool

# %%
h=True
d(h)
type (h)
# Out:
# True
# bool

# %%
h=int(h)
print (h)
type (h)
# Out:
# 1
# int

# %% [markdown]
# #Operator Perbandingan

# %%
print (6>=6)
# Out:
# True

# %%
print (8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print (8<10)
# Out:
# True

# %%
print (8>10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print (7<=1 or 2!=2)
# Out:
# False

# %%
print (not(0==1 and 1!=1))
# Out:
# True

# %%
print (not(5<10 or 5<=10))
# Out:
# False

# %% [markdown]
# #Latihan Soal

# %%
tinggi_nino = 170
berat_nino = 55
umur_nino = 23

syarat_tinggi = 165
syarat_berat = 50
syarat_umur_maksimal = 25

print("Tinggi:", tinggi_nino, "cm,", "Berat:", berat_nino, "kg,", "Umur:", umur_nino, "tahun")
# Out:
# Tinggi: 170 cm, Berat: 55 kg, Umur: 23 tahun

# %%
tinggi_nino = 170
berat_nino = 55
umur_nino = 23

print(tinggi_nino >=165 and berat_nino >=50 and umur_nino <=25)
# Out:
# True
